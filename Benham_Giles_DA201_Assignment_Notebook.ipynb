# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # Course 2: Data Analytics using Python

# %% [markdown]
# ## Assignment: Diagnostic Analysis using Python
#
# You’ll be working with real-world data to address a problem faced by the National Health Service (NHS). The analysis will require you to utilise Python to explore the available data, create visualisations to identify trends, and extract meaningful insights to inform decision-making.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 1

# %% [markdown]
# ### Insert proof of your GitHub repository. This can be a link or screenshot showing your repo.

# %%
# My GitHub repository.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 2

# %% [markdown]
# ### Prepare your workstation

# %%
# Import the necessary libraries.
import pandas as pd
import numpy as np

# Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
# Import and sense-check the actual_duration.csv data set as ad.
ad = pd.read_csv('actual_duration.csv')

# View the DataFrame.
print(ad.columns)
# Out:
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')

# %%
# Determine whether there are missing values.
print(ad.isna().sum())
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# dtype: int64

# %%
# Determine the metadata of the data set.
print(ad.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB
# None

# %%
# Determine the descriptive statistics of the data set.
ad.describe()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Import and sense-check the appointments_regional.csv data set as ar.
ar = pd.read_csv('appointments_regional.csv')

# View the DataFrame.
print(ar.columns)
# Out:
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')

# %%
# Determine whether there are missing values.
print(ar.isna().sum())
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# dtype: int64

# %%
# Determine the metadata of the data set.
print(ar.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB
# None

# %%
# Determine the descriptive statistics of the data set.
ar.describe()
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Import and sense-check the national_categories.xlsx data set as nc.
nc = pd.read_excel('national_categories.xlsx')

# View the DataFrame.
print(nc.columns)
# Out:
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')

# %%
# Determine whether there are missing values.
print(nc.isna().sum())
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
# Determine the metadata of the data set.
print(nc.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB
# None

# %%
# Determine the descriptive statistics of the data set.
nc.describe()
# Out:
#        count_of_appointments
# count          817394.000000
# mean              362.183684
# std              1084.576600
# min                 1.000000
# 25%                 7.000000
# 50%                25.000000
# 75%               128.000000
# max             16590.000000

# %% [markdown]
# ### Explore the data set

# %% [markdown]
# **Question 1:** How many locations are there in the data set?

# %%
# Determine the number of locations.

# Calculate the number of unique locations the dataset
count_of_locations = ad['sub_icb_location_code'].nunique()

# Display the number of unique locations
print(count_of_locations)


# Check the number of unique locations was correct
locations_check = nc['sub_icb_location_name'].nunique()

# Display the check
print("The number of locations in the dataset is", locations_check)
# Out:
# 106
# The number of locations in the dataset is 106

# %% [markdown]
# **Question 2:** What are the five locations with the highest number of records?

# %%
# Determine the top five locations based on record count.

# Group the nc dataframe by location
locations_grouped = nc.groupby('sub_icb_location_name')

# Create an empty list to store location count
count_of_records = []

# Calculate the count of records for each location
# Add the calculated values to the count of records list
for location_name, group_data in locations_grouped:
    count = len(group_data.index)
    count_of_records.append({
        'sub_icb_location_name': location_name, 'count': count})

# Create a Pandas DataFrame with the count of records list
count_of_records = pd.DataFrame(count_of_records)

# Sort the DataFrame by the count column in descending order
sorted_count_of_records = count_of_records.sort_values(
    by='count', ascending=False)

# View the DataFrame.
sorted_count_of_records.head()
# Out:
#                           sub_icb_location_name  count
# 76            NHS North West London ICB - W2U3Z  13007
# 47                NHS Kent and Medway ICB - 91Q  12637
# 21                          NHS Devon ICB - 15N  12526
# 36  NHS Hampshire and Isle Of Wight ICB - D9Y0V  12171
# 67            NHS North East London ICB - A3A8R  11837

# %%
# Display the result
print("The five locations with the highest number of records are") 
sorted_count_of_records["sub_icb_location_name"].head()
# Out:
# The five locations with the highest number of records are
# 76              NHS North West London ICB - W2U3Z
# 47                  NHS Kent and Medway ICB - 91Q
# 21                            NHS Devon ICB - 15N
# 36    NHS Hampshire and Isle Of Wight ICB - D9Y0V
# 67              NHS North East London ICB - A3A8R
# Name: sub_icb_location_name, dtype: object

# %% [markdown]
# **Question 3:** How many service settings, context types, national categories, and appointment statuses are there?

# %%
# Determine the number of service settings.

# calculate the number of service settings
# (this matches the number of service settings in the metadata)
service_setting_count = nc['service_setting'].nunique()

print("There are", service_setting_count, "service settings")
# Out:
# There are 5 service settings

# %%
# Determine the number of context types.

# calculate the number of context types
# (this matches the number of service settings in the metadata)
context_type_count = nc['context_type'].nunique()

# Display the result
print("There are", context_type_count, "context types")
# Out:
# There are 3 context types

# %%
# Determine the number of national categories.

# calculate the number of national categories
# (this matches the number of service settings in the metadata)
national_category_count = nc['national_category'].nunique()

# Display the result
print("There are", national_category_count, "national categories")
# Out:
# There are 18 national categories

# %%
# Determine the number of appointment status.

# calculate the number of appointment statuses
# (this matches the number of service settings in the metadata)
appointment_status_count = ar['appointment_status'].nunique()

# Display the result
print("There are", appointment_status_count, "appointment statuses")
# Out:
# There are 3 appointment statuses

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 3

# %% [markdown]
# ### Continue to explore the data and search for answers to more specific questions posed by the NHS.

# %% [markdown]
# **Question 1:** Between what dates were appointments scheduled?

# %%
# View the first five rows of appointment_date for the ad DataFrame to determine the date format.
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
# View the first five rows of appointment_date for the nc DataFrame to determine the date format.
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Change the date format of ad['appointment_date'].

# import datetime module
from datetime import datetime

# change date format 
ad['appointment_date'] = pd.to_datetime(ad['appointment_date'], 
                                        format='%d-%b-%y')

# View the DateFrame.
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0       2021-12-01           31-60 Minutes                    364
# 1       2021-12-01           21-30 Minutes                    619
# ...

# %%
# Change the date format of nc['appointment_date'].
nc['appointment_date'] = pd.to_datetime(nc['appointment_date'], 
                                        format='%d-%b-%y')

nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Change the date format of ar['appointment_month'].

# change date format 
ar['appointment_month'] = pd.to_datetime(ar['appointment_month'],
                                    format='%Y-%m').dt.strftime('%Y-%m')

# View the DateFrame.
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# Determine the minimum and maximum dates in the ad DataFrame.
# Use appropriate docstrings.
print("The appointments in the ad dataframe were scheduled between",ad.min\
()['appointment_date'].date(), "and", ad.max()['appointment_date'].date())
# Out:
# The appointments in the ad dataframe were scheduled between 2021-12-01 and 2022-06-30

# %%
# Determine the minimum and maximum dates in the nc DataFrame.
# Use appropriate docstrings.
print("The appointments in the nc dataframe were scheduled between",nc.min\
()['appointment_date'].date(), "and", nc.max()['appointment_date'].date())
# Out:
# The appointments in the nc dataframe were scheduled between 2021-08-01 and 2022-06-30

# %%
# Determine the minimum and maximum dates in the ar DataFrame.

print("The appointments in the ar dataframe were scheduled between",ar.min\
()['appointment_month'], "and", ar.max()['appointment_month'])
# Out:
# The appointments in the ar dataframe were scheduled between 2020-01 and 2022-06

# %% [markdown]
# **Question 2:** Which service setting was the most popular for NHS North West London from 1 January to 1 June 2022?

# %%
# For each of these service settings, determine the number of records available for the period and the location. 

# Create the subset of the nc dataframe, called nc_subset specifying the 
# location as NHS North West London, and the dates as Jan - June 2022
nc_subset = nc[(nc['sub_icb_location_name'] == \
                'NHS North West London ICB - W2U3Z') &
              (nc['appointment_month'] >= '2022-01') &
              (nc['appointment_month'] <= '2022-06')]

# Calculate the popularity of each service setting
group_service_appointments = nc_subset.groupby('service_setting')

# View the output.
group_service_appointments.sum()
# Out:
#                            count_of_appointments
# service_setting
# Extended Access Provision                 115052
# General Practice                         5719516
# Other                                     181576
# Primary Care Network                      130526
# Unmapped                                  462758

# %% [markdown]
# **Question 3:** Which month had the highest number of appointments?

# %%
# Change the datatype for appointment_month to datetime
nc['appointment_month'] = pd.to_datetime(nc['appointment_month'], 
                                         format='%Y-%m')

# %%
# Number of appointments per month == sum of count_of_appointments by month.
# Use the groupby() and sort_values() functions.

# Use groupby and sortvalues cuntion to calculate number of 
# appointments per month
nc['count_of_appointments'].groupby([nc['appointment_month'].dt.year,\
                                     nc['appointment_month'].dt.month])\
                                     .sum().sort_values(ascending=False)
# Out:
# appointment_month  appointment_month
# 2021               11                   30405070
#                    10                   30303834
# 2022               3                    29595038
# 2021               9                    28522501
# 2022               5                    27495508
#                    6                    25828078
#                    1                    25635474
#                    2                    25355260
# 2021               12                   25140776
# 2022               4                    23913060
# 2021               8                    23852171
# Name: count_of_appointments, dtype: int64

# %% [markdown]
# **Question 4:** What was the total number of records per month?

# %% [markdown]
# Total number of records per month (NC dataframe)

# %%
#total records of per month for the NC dataframe

# Use groupby and sortvalues cuntion to calculate number of 
# appointments per month
nc['count_of_appointments'].groupby([nc['appointment_date'].dt.year,\
                                     nc['appointment_date'].dt.month])\
                                     .size().sort_values(ascending=False)
# Out:
# appointment_date  appointment_date
# 2022              3                   82822
# 2021              11                  77652
# 2022              5                   77425
# 2021              9                   74922
# 2022              6                   74168
# 2021              10                  74078
#                   12                  72651
# 2022              1                   71896
#                   2                   71769
#                   4                   70012
# 2021              8                   69999
# Name: count_of_appointments, dtype: int64

# %% [markdown]
# Total number of records per month (all dataframes)

# %%
# Change the datatype for appointment_month to datetime
ar['appointment_month'] = pd.to_datetime(ar['appointment_month'],
                                         format='%Y-%m')

# %%
# Create appointment month series in the ad dataframe
ad['appointment_month'] = pd.to_datetime(ad['appointment_date']
                                         .dt.strftime('%Y-%m'), format='%Y-%m')

# %%
# Combine the three dataframes with the concat() function
combined_df = pd.concat([nc, ar, ad], axis=0, ignore_index=True)

# %%
# Use groupby and sortvalues cuntion to calculate number of 
# appointments per month
combined_df['count_of_appointments'].\
groupby([combined_df['appointment_month'].dt.year,
         combined_df['appointment_month'].dt.month])\
         .size().sort_values(ascending=False)
# Out:
# appointment_month  appointment_month
# 2022               3                    124590
#                    5                    117829
#                    6                    113626
# 2021               12                   112551
# 2022               1                    111764
#                    2                    110876
#                    4                    109163
# 2021               11                    98418
#                    9                     95363
#                    10                    94640
#                    8                     89785
# 2020               3                     21350
#                    1                     20889
#                    2                     20689
#                    10                    20122
#                    9                     20043
# 2021               7                     19899
#                    6                     19814
# 2020               11                    19675
# ...

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 4

# %% [markdown]
# ### Create visualisations and identify possible monthly and seasonal trends in the data.

# %%
# Import the necessary libraries.
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Set the tick style.
sns.set_style('ticks')

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %%
# Change the data type of the appointment month to string to allow for easier plotting.
nc['appointment_month'] = nc['appointment_month'].dt.strftime('%Y-%m')

# %% [markdown]
# **Service settings:**

# %%
# Aggregate on monthly level and determine the sum of records per month
nc_ss = nc.groupby(['appointment_month', 'service_setting'])\
['count_of_appointments'].sum().reset_index()

#View output
nc_ss.head()
# Out:
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 1           2021-08           General Practice               21575852
# 2           2021-08                      Other                 449101
# 3           2021-08       Primary Care Network                 432448
# 4           2021-08                   Unmapped                1233843

# %%
# Plot the appointments over the available date range, and review the service settings for months.
# Create a lineplot
ax = sns.lineplot(x='appointment_month', y='count_of_appointments',
             hue='service_setting', data=nc_ss, ci=None, palette='colorblind')

# Customise tick labels for y axis
ax.set_yticklabels(['', '0', '5M', '10M', '15M', '20M', '25M'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Count of Appointments (Millions)")
ax.set_title("Count of Appointments per Month by Service Setting")
# Out:
# Text(0.5, 1.0, 'Count of Appointments per Month by Service Setting')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that the number of GP appointments stays relativley stable over time, with the general practice (GP) service setting being by far the most common. Also it may be notable that the number of unmapped appointments has gone down in this time.

# %% [markdown]
# **Context types:**

# %%
# Create a separate data set that can be used in future weeks. 
# Aggregate on monthly level and determine the sum of records per month
nc_ct = nc.groupby(['appointment_month', 'context_type'])\
['count_of_appointments'].sum().reset_index()

# View output.
nc_ct.head()
# Out:
#   appointment_month            context_type  count_of_appointments
# 0           2021-08  Care Related Encounter               20255235
# 1           2021-08    Inconsistent Mapping                2363093
# 2           2021-08                Unmapped                1233843
# 3           2021-09  Care Related Encounter               24404251
# 4           2021-09    Inconsistent Mapping                2782135

# %%
# Plot the appointments over the available date range, and review the context types for months.
# Create a lineplot
ax = sns.lineplot(x='appointment_month', y='count_of_appointments',
             hue='context_type', data=nc_ct, ci=None, palette='colorblind')


# Customise tick labels for y axis
ax.set_yticklabels(['', '0', '5M', '10M', '15M', '20M', '25M'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Count of Appointments (Millions)")
ax.set_title("Count of Appointments per Month by Context Type")
# Out:
# Text(0.5, 1.0, 'Count of Appointments per Month by Context Type')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that the number of GP appointments stays relativley stable over time, and that the vast majority appointments fall in the care related encounter context type. Also it may be notable that there are relatively few appointments which have inconsistent mapping or are unmapped(around 10-15%)

# %% [markdown]
# **National categories:**

# %%
# Create a separate data set that can be used in future weeks. 
# Aggregate on monthly level and determine the sum of records per month
nc_nc = nc.groupby(['appointment_month', 'national_category'])\
['count_of_appointments'].sum().reset_index()

# View output.
nc_nc.head()
# Out:
#   appointment_month                                  national_category  \
# 0           2021-08  Care Home Needs Assessment & Personalised Care...
# 1           2021-08                                    Care Home Visit
# 2           2021-08                                    Clinical Triage
# 3           2021-08                         General Consultation Acute
# 4           2021-08                       General Consultation Routine
#
#    count_of_appointments
# 0                  29676
# 1                  47583
# 2                3704207
# 3                4280920
# 4                7756045

# %%
# Plot the appointments over the available date range, and review the national categories for months.
# Create a lineplot
ax = sns.lineplot(x='appointment_month', y='count_of_appointments',
             hue='national_category', data=nc_nc, ci=None, palette='colorblind')

# Customise tick labels for y axis
ax.set_yticklabels(['', '0.0', '2M', '4M', '6M', '8M', '10M'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Count of Appointments (Millions)")
ax.set_title("Count of Appointments per Month by National Category")

# Move legend to below the graph
ax.legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=3)

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that the number of GP appointments stays relativley stable over time, general consultation routine was the most common national category, followed by general consultation acute, and clinical triage.

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (August 2021), autumn (October 2021), winter (January 2022), and spring (April 2022).

# %% [markdown]
# **Summer (August 2021):**

# %%
# Create a separate data set that can be used in future weeks. 
nc_ss_day = nc.groupby(['appointment_date', 'appointment_month', 'service_setting'])\
['count_of_appointments'].sum().reset_index()


# View output.
nc_ss_day.head()
# Out:
#   appointment_date appointment_month            service_setting  \
# 0       2021-08-01           2021-08  Extended Access Provision
# 1       2021-08-01           2021-08           General Practice
# 2       2021-08-01           2021-08                      Other
# 3       2021-08-01           2021-08       Primary Care Network
# 4       2021-08-01           2021-08                   Unmapped
#
#    count_of_appointments
# 0                    438
# 1                   3411
# 2                    401
# 3                    323
# 4                   1054

# %%
# Change nc_ss_day['appointment_date'] dtype to string
nc_ss_day['appointment_date'] = nc_ss_day['appointment_date'].astype(str)

# %%
# Look at August 2021 in more detail to allow a closer look.

# Create a lineplot
ax = sns.lineplot(x='appointment_date', y='count_of_appointments',
             hue='service_setting', 
             data=nc_ss_day[nc_ss_day['appointment_month'] == '2021-08'], 
             palette='colorblind')

# Customise tick labels for y axis
ax.set_yticklabels(['', '0', '0.2M', '0.4M', '0.6M', '0.8M', '1.0M'])

# Rotate the x axis ticks by 45 degrees
plt.xticks(rotation=45)

# Specify the labels
ax.set_xlabel("Appointment Day")
ax.set_ylabel("Count of Appointments (Millions)")
ax.set_title("Count of Appointments per Day by Service Setting")
# Out:
# Text(0.5, 1.0, 'Count of Appointments per Day by Service Setting')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that the day with the highest number of appointments each week is Monday, with appointment count trends down during the week and ends with the weekend with very little appointments. The amount of appointments each week in August is relativley stable, with weekdays seeing between around 950k and 1.1M appointments in the GP service setting, and less than 500k of the other service settings.

# %% [markdown]
# **Autumn (October 2021):**

# %%
# Look at October 2021 in more detail to allow a closer look.

# Create a lineplot
ax = sns.lineplot(x='appointment_date', y='count_of_appointments',
             hue='service_setting', 
             data=nc_ss_day[nc_ss_day['appointment_month'] == '2021-10'],
             palette='colorblind')

# Customise tick labels for y axis
ax.set_yticklabels(['', '0', '0.2M', '0.4M', '0.6M', '0.8M', '1.0M', '1.2M', '1.4M'])


# Rotate the x axis ticks by 45 degrees
plt.xticks(rotation=45)

# Specify the labels
ax.set_xlabel("Appointment Day")
ax.set_ylabel("Count of Appointments (Millions)")
ax.set_title("Count of Appointments per Day by Service Setting")
# Out:
# Text(0.5, 1.0, 'Count of Appointments per Day by Service Setting')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that the day with the highest number of appointments each week is Monday, with appointment count trends down during the week and ends with the weekend with very little appointments. The amount of appointments each week in October is relativley stable, with a slight drop off towards the end of the month. Weekdays saw between around 1.1M and 1.3M appointments in the GP service setting, and less than 500k of the other service settings.

# %% [markdown]
# **Winter (January 2022):**

# %%
# Look at January 2022 in more detail to allow a closer look.

# Create a lineplot.
ax = sns.lineplot(x='appointment_date', y='count_of_appointments',
             hue='service_setting',
             data=nc_ss_day[nc_ss_day['appointment_month'] == '2022-01'],
             palette='colorblind')

# Customise tick labels for y axis
ax.set_yticklabels(['', '0', '0.2M', '0.4M', '0.6M', '0.8M', '1.0M', '1.2M'])

# Rotate the x axis ticks by 45 degrees
plt.xticks(rotation=45)

# Specify the labels
ax.set_xlabel("Appointment Day")
ax.set_ylabel("Count of Appointments (Millions)")
ax.set_title("Count of Appointments per Day by Service Setting")
# Out:
# Text(0.5, 1.0, 'Count of Appointments per Day by Service Setting')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that the day with the highest number of appointments each week is Monday, with appointment count trends down during the week and ends with the weekend with very little appointments. The amount of appointments each week in January is relativley stable. Weekdays saw between around 1.1M and 1.25M appointments in the GP service setting, and less than 500k of the other service settings. There are less unmapped appointments in this month than previous months.

# %% [markdown]
# **Spring (April 2022):**

# %%
# Look at April 2022 in more detail to allow a closer look.

# Create a lineplot.
ax = sns.lineplot(x='appointment_date', y='count_of_appointments',
             hue='service_setting', 
             data=nc_ss_day[nc_ss_day['appointment_month'] == '2022-04'], 
             palette='colorblind')

# Customise tick labels for y axis
ax.set_yticklabels(['', '0', '0.2M', '0.4M', '0.6M', '0.8M', '1.0M', '1.2M'])

# Rotate the x axis ticks by 45 degrees
plt.xticks(rotation=45)

# Specify the labels
ax.set_xlabel("Appointment Day")
ax.set_ylabel("Count of Appointments (Millions)")
ax.set_title("Count of Appointments per Day by Service Setting")
# Out:
# Text(0.5, 1.0, 'Count of Appointments per Day by Service Setting')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that the day with the highest number of appointments each week is Monday, with appointment count trends down during the week and ends with the weekend with very little appointments. The amount of appointments each week in April is relativley stable. Weekdays saw between around 1.1M and 1.25M appointments in the GP service setting, and less than 500k of the other service settings. Similar to January, there are less unmapped appointments in this month than previous months.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
# Libraries and settings needed for analysis
import pandas as pd
import seaborn as sns

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

# %%
# Load the data set.
tw = pd.read_csv('tweets.csv')

# View the DataFrame.
print(tw.columns)
tw.head()
# Out:
# Index(['tweet_id', 'tweet_full_text', 'tweet_entities',
#        'tweet_entities_hashtags', 'tweet_metadata', 'tweet_retweet_count',
#        'tweet_favorite_count', 'tweet_favorited', 'tweet_retweeted',
#        'tweet_lang'],
#       dtype='object')
#               tweet_id  \
# 0  1567629223795527681
# 1  1567582846612553728
# 2  1567582787070304256
# 3  1567582767625428992
# 4  1567582720460570625
#
#                                                                                                                                                                                            tweet_full_text  \
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# ...

# %%
# Explore the metadata.
print(tw.describe())
print(tw.info())
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
# ...

# %%
# Explore the data set.
print(tw['tweet_retweet_count'].value_counts())
print(tw['tweet_favorite_count'].value_counts())
# Out:
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: tweet_retweet_count, dtype: int64
# 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: tweet_favorite_count, dtype: int64

# %%
# Would it be useful to only look at retweeted and favourite tweet messages?
# Explain your answer.

""" 
I believe there are advantages and disadvantages of only looking at retweeted and
favourited tweets. I would place more weight on findings from tweets with 
retweets and favourites, but I would not wholly ignore tweets without such engagement.


Advantages of only using retweeted and favourited tweet messages

- Bot screening - The CEO of Twitter (Elon Musk) has publically discussed Twitter's problem
  with bots. Ignoring tweets without retweets or favourites may help filter out 
  bot-generated tweets, as bots often don't receive much engagement. This will help
  improve the reliability of the dataset. 
  
- Relevance - Tweets receiving engagement indicates that the tweet's content has resonated with someone. 
  This can be interpreted as a signal of relevance or importance, meaning that the tweet may have data 
  that is useful for our analysis. 

Disadvantages of only using retweeted and favourite tweet messages

- Bias - Analysing only retweeted and favourited tweets may overrepresent popular or 
  contentious discussions, as they typically receive more engagement, potentially overlooking 
  important but less engaged-with content.
  

- Loss of potentially useful information - By filtering out tweets without engagement
  we may end up ignoring tweets with valuable information that could help us achieve our
  objectives.

"""
# Out:
# " \nI believe there are advantages and disadvantages of only looking at retweeted and\nfavourited tweets. I would place more weight on findings from tweets with \nretweets and favourites, but I would not wholly ignore tweets without such engagement.\n\n\nAdvantages of only using retweeted and favourited tweet messages\n\n- Bot screening - The CEO of Twitter (Elon Musk) has publically discussed Twitter's problem\n  with bots. Ignoring tweets without retweets or favourites may help filter out \n  bot-generated tweets, as bots often don't receive much engagement. This will help\n  improve the reliability of the dataset. \n  \n- Relevance - Tweets receiving engagement indicates that the tweet's content has resonated with someone. \n  This can be interpreted as a signal of relevance or importance, meaning that the tweet may have data \n  that is useful for our analysis. \n\nDisadvantages of only using retweeted and favourite tweet messages\n\n- Bias - Analysing only retweeted and favourit
# ...

# %%
# Create a new DataFrame containing only the text.
tweets_text = tw[['tweet_full_text']]


# View the DataFrame.
tweets_text.head()
# Out:
#                                                                                                                                                                                            tweet_full_text
# 0  As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                              RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                           RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# ...

# %%
# Create a variable (tags,) and assign an empty list to it.
tags = []

# %%
# Loop through the messages, and create a list of values containing the # symbol.
for y in [x.split(' ') for x in tw['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lowercase.
            tags.append(z.lower())
            
# Create a Pandas Series to count the values in the list      
tags_series = pd.Series(tags)

# %%
# Display the first 30 records.
print(tags_series.value_counts().head(30))
# Out:
# #healthcare                    716
# #health                         80
# #medicine                       41
# #ai                             40
# #job                            38
# #medical                        35
# #strategy                       30
# #pharmaceutical                 28
# #digitalhealth                  25
# #pharma                         25
# #marketing                      25
# #medtwitter                     24
# #biotech                        24
# #competitiveintelligence        24
# #meded                          23
# #vaccine                        18
# #hiring                         18
# #news                           17
# #machinelearning                17
# #technology                     17
# #coronavirus                    16
# #womeninmedicine                16
# #covid                          16
# #competitivemarketing           16
# #wellness                       15
# #healthtech                     15
# #doctorofveterinarymedicine     14
# ...

# %%
# Convert the series to a DataFrame in preparation for visualisation.
hashtags = tags_series.value_counts().reset_index()

# Rename the columns.
hashtags.columns = ['word', 'count']

# %%
# Fix the count datatype.
hashtags['count'] = hashtags['count'].astype(int)

# View the result.
hashtags.head()
# Out:
#           word  count
# 0  #healthcare    716
# 1      #health     80
# 2    #medicine     41
# 3          #ai     40
# 4         #job     38

# %%
# Display records where the count is larger than 10.
# Filter the data
hashtags1 = hashtags[hashtags['count'] > 10]
                     
# Display the data
hashtags1.head()
# Out:
#           word  count
# 0  #healthcare    716
# 1      #health     80
# 2    #medicine     41
# 3          #ai     40
# 4         #job     38

# %%
# Create a Seaborn barplot indicating records with a count >10 records.
# Create the plot.
sns.barplot(x='count', y='word', data=hashtags1)
plt.title('Trending Hashtags')

# View the barplot.
plt.show()

# %% [markdown]
# A Seaborn barplot was used to display the data as barplots are an effective tool for displaying catigorical data.
#
# From this visualisation you you can observe that #healthcare is by far the most used healthcare related hashtag in the UK, with over 9x more usage than the next most used hashtag #health.

# %%
# Filter the data again to remove over represented hashtags
hashtags2 = hashtags1[hashtags['count'] < 100]
                     
# Display the data
hashtags2.head(30)
# Out:
#                            word  count
# 1                       #health     80
# 2                     #medicine     41
# 3                           #ai     40
# 4                          #job     38
# 5                      #medical     35
# 6                     #strategy     30
# 7               #pharmaceutical     28
# 8                #digitalhealth     25
# 9                       #pharma     25
# 10                   #marketing     25
# 11                  #medtwitter     24
# 12                     #biotech     24
# 13     #competitiveintelligence     24
# 14                       #meded     23
# 15                     #vaccine     18
# 16                      #hiring     18
# 17                        #news     17
# 18             #machinelearning     17
# 19                  #technology     17
# 20                 #coronavirus     16
# 21             #womeninmedicine     16
# 22                       #covid     16
# 23        #competitivemarketing     16
# ...

# %%
# Create a Seaborn barplot with to remove over represented hashtags
# Create the plot.
sns.barplot(x='count', y='word', data=hashtags2)
plt.title('Trending Hashtags Excluding "#Healthcare"')

# View the barplot.
plt.show()

# %% [markdown]
# A Seaborn barplot was used to display the data as barplots are an effective tool for displaying catigorical data. #Healthcare was filtered out so it's easier to compare the popularity of other trending hashtags.
#
# From this visualisation you you can observe that #health is still far more popular than other hashtags, followed by #medicine and #AI.

# %%
# Filter the data again to ignore hashtags with a count of > 20
hashtags3 = hashtags2[(hashtags['count'] > 20)]
                     
# Display the data
hashtags3
# Out:
#                         word  count
# 1                    #health     80
# 2                  #medicine     41
# 3                        #ai     40
# 4                       #job     38
# 5                   #medical     35
# 6                  #strategy     30
# 7            #pharmaceutical     28
# 8             #digitalhealth     25
# 9                    #pharma     25
# 10                #marketing     25
# 11               #medtwitter     24
# 12                  #biotech     24
# 13  #competitiveintelligence     24
# 14                    #meded     23

# %%
# Create an improved 
ax = sns.barplot(x='count', y='word', data=hashtags3)
ax.set_title('Trending Hashtags (Excluding #Healthcare)', size=25)
ax.set_xlabel('Tweet Count', size=20)
ax.set_ylabel('')

# Edit the size of the tick labels for the x axis
ax.tick_params(axis='x', labelsize=15)

# Hide the y axis tick labels
ax.set_yticklabels([])

# Add labels inside each bar
for i, (index, row) in enumerate(hashtags3.iterrows()):
    ax.text(1, i, row['word'], va='center', color='black', size=18)


# View the barplot.
plt.show()

# %% [markdown]
# A Seaborn barplot was used to display the data as barplots are an effective tool for displaying catigorical data. The dataset used in the barplot was filtered again, with the intention of cutting down the large amount of bars on the screen, allowing stakeholders to get a better understanding of what the trends were in the trending healthcare hashtags.
#
# One interesting observation from this chart is the reoccuring theme of technology like ai, biotech, competitiveintelligence suggesting the public is interested in how we might apply technology to our healthcare system in the UK.

# %% [markdown]
# # Assignment activity 6 Question 5
#
# Deterine how your team can utilise tweets to provide feedback to the stakeholders?
# 5A) The team can utilise Tweets to provide feedback to stakeholders by including the #healthcare hashtag so that it appears on the feed of people who are following or tweeting about healthcare. This is the relevant twitter hashtag with the most engagement in the dataset so tweeting using the hashtag will get the message to the most people.
#
#
# Determine whether the tweets add value to the overall project
# 5B) It is not clear that twitter will add value to this project, when we are trying to reduce the number of missed appointments.
#
# Deterimine how the NHS can utilise tweets.
# 5C)The NHS may use it to try and bring awareness to the problem of missing appointments costing them money, by tweeting about it to the #healthcare hashtag.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 6

# %% [markdown]
# ### Investigate the main concerns posed by the NHS.

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# %%
# Print the min and max dates.
print(ar.min()['appointment_month'])
print(ar.max()['appointment_month'])
# Out:
# 2020-01-01 00:00:00
# 2022-06-01 00:00:00

# %%
# Filter the data set to only look at data from 2021-08 onwards.
ar_filtered = ar[ar['appointment_month'] >= '2021-08']

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
# Create an aggregated data set to review the different features.
ar_agg = ar_filtered.groupby(['appointment_month', 'hcp_type', 'appointment_status',
                             'appointment_mode', 'time_between_book_and_appointment'])
# View the DataFrame.
ar_agg.head()
# Out:
#        icb_ons_code appointment_month appointment_status  \
# 3652      E54000034        2021-08-01           Attended
# 3653      E54000034        2021-08-01           Attended
# 3654      E54000034        2021-08-01           Attended
# 3655      E54000034        2021-08-01           Attended
# 3656      E54000034        2021-08-01           Attended
# ...             ...               ...                ...
# 583830    E54000050        2021-08-01                DNA
# 585277    E54000050        2022-02-01            Unknown
# 594965    E54000050        2021-08-01                DNA
# 595510    E54000050        2021-11-01                DNA
# 595692    E54000050        2021-12-01                DNA
#
#                     hcp_type appointment_mode  \
# 3652                      GP     Face-to-Face
# 3653                      GP     Face-to-Face
# 3654                      GP     Face-to-Face
# 3655                      GP     Face-to-Face
# ...

# %%
# Determine the total number of appointments per month.
ar_df = ar_agg['count_of_appointments'].sum().groupby('appointment_month')\
.sum().reset_index(name='sum_of_appointments')

# View the DataFrame.
ar_df
# Out:
#    appointment_month  sum_of_appointments
# 0         2021-08-01             23852171
# 1         2021-09-01             28522501
# 2         2021-10-01             30303834
# 3         2021-11-01             30405070
# 4         2021-12-01             25140776
# 5         2022-01-01             25635474
# 6         2022-02-01             25355260
# 7         2022-03-01             29595038
# 8         2022-04-01             23913060
# 9         2022-05-01             27495508
# 10        2022-06-01             25828078

# %%
# Add a new column to indicate the average utilisation of services.
# Monthly aggregate / 30 to get to a daily value.
ar_df['utilisation'] = (ar_df['sum_of_appointments'] / 30).round(1)

# View the DataFrame.
print(ar_df)
# Out:
#    appointment_month  sum_of_appointments  utilisation
# 0         2021-08-01             23852171     795072.4
# 1         2021-09-01             28522501     950750.0
# 2         2021-10-01             30303834    1010127.8
# 3         2021-11-01             30405070    1013502.3
# 4         2021-12-01             25140776     838025.9
# 5         2022-01-01             25635474     854515.8
# 6         2022-02-01             25355260     845175.3
# 7         2022-03-01             29595038     986501.3
# 8         2022-04-01             23913060     797102.0
# 9         2022-05-01             27495508     916516.9
# 10        2022-06-01             25828078     860935.9

# %%
# Add a new column to indicate the average capacity utilisation of services
ar_df['capcacity_utilisation'] = (ar_df['utilisation'] / 1200000).round(3)

# View the DataFrame.
ar_df
# Out:
#    appointment_month  sum_of_appointments  utilisation  capcacity_utilisation
# 0         2021-08-01             23852171     795072.4                  0.663
# 1         2021-09-01             28522501     950750.0                  0.792
# 2         2021-10-01             30303834    1010127.8                  0.842
# 3         2021-11-01             30405070    1013502.3                  0.845
# 4         2021-12-01             25140776     838025.9                  0.698
# 5         2022-01-01             25635474     854515.8                  0.712
# 6         2022-02-01             25355260     845175.3                  0.704
# 7         2022-03-01             29595038     986501.3                  0.822
# 8         2022-04-01             23913060     797102.0                  0.664
# 9         2022-05-01             27495508     916516.9                  0.764
# 10        2022-06-01             25828078     860935.9                  0.717

# %%
# Plot sum of count of monthly visits.
# Convert the appointment_month to string data type for ease of visualisation.
ar_df['appointment_month'] = ar_df['appointment_month'].astype(str)

# Create a lineplot with Seaborn.
ax =sns.lineplot(x='appointment_month', y='sum_of_appointments', data=ar_df)

# Customise tick labels for y axis
ax.set_yticklabels(['', '24M', '25M', '26M', '27M', '28M', '29M', '30M'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Count of appointments (Millions)")
ax.set_title("Count of Appointments per Month")
# Out:
# Text(0.5, 1.0, 'Count of Appointments per Month')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that the capacity utilisation of GP appointments per month fluctuates from 24M-30.4M.

# %%
# Plot monthly capacity utilisation.
# Create a lineplot.
ax = sns.lineplot(x='appointment_month', y='capcacity_utilisation', data=ar_df)

# Customise tick labels for y axis
ax.set_yticklabels(['', '67.5%', '70.0%', '72.5%', '75.0%', '77.5%', '80.0%', '82.5%', '85.0%'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Capacity Utilisation")
ax.set_title("Capacity Utilisation by Month")
# Out:
# Text(0.5, 1.0, 'Capacity Utilisation by Month')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that the capacity utilisation of GP appointments per month fluctuates from 67.5% - 85%.

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# Determine the number of appointments per month by hpc type
ar_hpc = ar.groupby(['appointment_month', 'hcp_type']).sum().reset_index()

# View the DataFrame.
ar_hpc.head()
# Out:
#   appointment_month              hcp_type  count_of_appointments
# 0        2020-01-01                    GP               14168932
# 1        2020-01-01  Other Practice staff               12326031
# 2        2020-01-01               Unknown                 704333
# 3        2020-02-01                    GP               12467976
# 4        2020-02-01  Other Practice staff               11002550

# %%
# Create a line plot to answer the question.
ax = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='hcp_type', data=ar_hpc)

# Customise tick labels for y axis
ax.set_yticklabels(['', '0', '2.0M', '4.0M', '6.0M', '8.0M', '10M', '12M', '14M'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Count of Appointments (Millions)")
ax.set_title("Count of Appointments by Month by HPC Type")
# Out:
# Text(0.5, 1.0, 'Count of Appointments by Month by HPC Type')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that there is a simlar amount of appointments with GP staff as there is with other staff such as Acupuncturist, Chiropodist, Community Psychiatric Nurse, Counsellor, Dispenser, District Nurse, Health Visitor, Interpreter/Link Worker, Osteopath, Other Practice Staff, Physiotherapist, Practice Nurse

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Filter the data to include only 'home_visits' from 'appointment_mode'
ar_home_visits = ar[ar['appointment_mode'] == 'Home Visit']

# Determine the number of appointments per month by appointment status
ar_visits = ar_home_visits.groupby(['appointment_month', 'appointment_status']).sum().reset_index()

# View the DataFrame
ar_visits
# Out:
#    appointment_month appointment_status  count_of_appointments
# 0         2020-01-01           Attended                 184531
# 1         2020-01-01                DNA                   8400
# 2         2020-01-01            Unknown                  74011
# 3         2020-02-01           Attended                 157118
# 4         2020-02-01                DNA                   7417
# ..               ...                ...                    ...
# 85        2022-05-01                DNA                   6806
# 86        2022-05-01            Unknown                  38222
# 87        2022-06-01           Attended                 146648
# 88        2022-06-01                DNA                   6018
# 89        2022-06-01            Unknown                  34974
#
# [90 rows x 3 columns]

# %%
# Pivot the ar_status DataFrame 
ar_visits = ar_visits.pivot_table(index='appointment_month', columns='appointment_status', values='count_of_appointments')

# Calculate the ratio of missed to attended appointments for each month
ar_visits['missed_to_attended_ratio'] = ar_visits['DNA'] / ar_visits['Attended']

# Display the resulting dataframe
ar_visits.head()
# Out:
# appointment_status  Attended   DNA  Unknown  missed_to_attended_ratio
# appointment_month
# 2020-01-01            184531  8400    74011                  0.045521
# 2020-02-01            157118  7417    63400                  0.047207
# 2020-03-01            116242  6682    49849                  0.057484
# 2020-04-01             72780  3524    24369                  0.048420
# 2020-05-01             83708  4178    24132                  0.049912

# %%
# Create a line plot to answer the question.
ax = sns.lineplot(x='appointment_month', y='missed_to_attended_ratio', data=ar_visits)

# Customise tick labels for y axis
ax.set_yticklabels(['', '3.0%', '3.5%', '4.0%', '4.5%', '5.0%', '5.5%'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Missed to Attend Ratio")
ax.set_title("The Ratio of Missed to Attended Home Visit Appointments Over Time")
# Out:
# Text(0.5, 1.0, 'The Ratio of Missed to Attended Home Visit Appointments Over Time')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that there a significant change in the ammount of home visit appointments missed over time. There is an uptrend from the start of 2020 to the end of 2021, after that the ammount of visit appointments missed declines significantly. The uptrend throughout late 2020 and 2021 may have been caused by the pandemic.

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
# Determine the number of appointments per month by appointment mode / type
ar_type = ar.groupby(['appointment_month', 'appointment_mode']).sum().reset_index()

# View the DataFrame.
ar_type.head()
# Out:
#   appointment_month appointment_mode  count_of_appointments
# 0        2020-01-01     Face-to-Face               21733394
# 1        2020-01-01       Home Visit                 266942
# 2        2020-01-01        Telephone                3701775
# 3        2020-01-01          Unknown                1302979
# 4        2020-01-01     Video/Online                 194206

# %%
# Create a line plot to answer the question.
ax = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='appointment_mode', data=ar_type)

# Customise tick labels for y axis
ax.set_yticklabels(['', '0', '5.0M', '10M', '15M', '20M'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Count of appointments (Millions)")
ax.set_title("Count of Appointments per Month by Appointment Type")
# Out:
# Text(0.5, 1.0, 'Count of Appointments per Month by Appointment Type')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that there a significant change in the GP appointment types, the number of telephone appointments doubled in the space of 3 or 4 months during the start of Covid. There was a decline in the amount of face-to-face appointments at the start of 2020 but it has been going back up since then. These changes may have been caused by the pandemic.

# %% [markdown]
# **Question 5:** Are there any trends in time between booking an appointment?

# %%
# Determine the number of appointments per month by time between booking an appointment
ar_time = ar.groupby(['appointment_month', 'time_between_book_and_appointment'])\
.sum().reset_index()

# View the DataFrame
ar_time.head()
# Out:
#   appointment_month time_between_book_and_appointment  count_of_appointments
# 0        2020-01-01                             1 Day                1945711
# 1        2020-01-01                    15  to 21 Days                1881819
# 2        2020-01-01                       2 to 7 Days                5604909
# 3        2020-01-01                    22  to 28 Days                1313557
# 4        2020-01-01                     8  to 14 Days                3444637

# %%
# Create a line plot to answer the question.
ax = sns.lineplot(x='appointment_month', y='count_of_appointments', hue='time_between_book_and_appointment', data=ar_time)

# Customise tick labels for y axis
ax.set_yticklabels(['', '0', '2.0M', '4.0M', '6.0M', '8.0M', '10M', '12M'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Count of appointments (Millions)")
ax.set_title("Count of Appointments per Month by Time Between Book and Appointment")
# Out:
# Text(0.5, 1.0, 'Count of Appointments per Month by Time Between Book and Appointment')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can observe that there doesn't seem to be a significant change in wait times. However it may be important to note that while the wait times overall don't appear to have changed, this may not be the case for individaul GP practices.

# %% [markdown]
# **Question 6:** How do the spread of service settings compare?

# %%
# Let's go back to the national category DataFrame you created in an earlier assignment activity.

# View the DataFrame
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Create a new DataFrame consisting of the month of appointment and the number of appointments.
nc_setting = nc.groupby(['appointment_month', 'service_setting']).sum().reset_index()

# View the DataFrame.
nc_setting.head()
# Out:
#   appointment_month            service_setting  count_of_appointments
# 0           2021-08  Extended Access Provision                 160927
# 1           2021-08           General Practice               21575852
# 2           2021-08                      Other                 449101
# 3           2021-08       Primary Care Network                 432448
# 4           2021-08                   Unmapped                1233843

# %%
# Create a boxplot to investigate spread of service settings.
ax = sns.boxplot(x='service_setting', y='count_of_appointments', data=nc_setting)

# Customise tick labels for y axis
ax.set_yticklabels(['', '0.0M', '5.0M', '10M', '15M', '20M', '25M'])

# Specify the labels
ax.set_xlabel("Service Setting")
ax.set_ylabel("Count of appointments (Millions)")
ax.set_title("Montly Appointments by Service Setting")
# Out:
# Text(0.5, 1.0, 'Montly Appointments by Service Setting')

# %% [markdown]
# A Seaborn boxplot was used to display the data as boxplots are an effective tool for analysing the distribution of appoinments between service settings, identifying outliers and assessing variablity in appoinment data.
#
# From this visualisation you can observe that the GP service setting is by far the most popular. The GP service setting has an IQR which spans from 21.9 million appointments per month to 25.2 million. The minimum value is 21.6 million appointments, and the maximum is 27.8 million. There are no outliers suggesting a relativley consistent distribution of appoinments.

# %%
# Create a new DataFrame excluding the 'General Practice' service setting
setting_ex_gp = nc_setting[nc_setting['service_setting'] != 'General Practice']

# Create a boxplot to investigate the service settings without GP.
ax = sns.boxplot(x='service_setting', y='count_of_appointments', data=setting_ex_gp)

# Customise tick labels for y axis
ax.set_yticklabels(['', '0.2M', '0.4M', '0.6M', '0.8M', '0.10M', '0.12M', '0.14M'])

# Specify the labels
ax.set_xlabel("Service Setting")
ax.set_ylabel("Count of appointments (Millions)")
ax.set_title("Montly Appointments by Service Setting (Excluding GP)")
# Out:
# Text(0.5, 1.0, 'Montly Appointments by Service Setting (Excluding GP)')

# %% [markdown]
# A Seaborn boxplot was used to display the data as boxplots are an effective tool for analysing the distribution of appoinments between service settings, identifying outliers and assessing variablity in appoinment data.
#
# From this visualisation you can tell unmapped is the next most common service setting in the data, with primary care network being the next most common actual service setting. All of the service settings have no outliers indicating a relativley consistent distribution of appointments.
#
#
# The distribution for each service setting is as follows:
#
# Extended Access Provision
# Lower Quartile - 187K,
# Upper Quartile - 210K,
# Median - 210K,
# Min - 161K,
# Max - 232K,
#
# Other
# Lower Quartile - 437K,
# Upper Quartile - 556K,
# Median - 465K,
# Min - 449K,
# Max - 559K,
#
# Primary Care Network
# Lower Quartile - 530K,
# Upper Quartile - 702K,
# Median - 585K,
# Min - 432K,
# Max - 614K,
#
# Unmapped
# Lower Quartile - 821K,
# Upper Quartile - 1.3M,
# Median - 1.2M,
# Min - 759K,
# Max - 1.4M,

# %% [markdown]
# # Extra analysis outside of assignment activities

# %% [markdown]
# Deterimine if the number of appointments that were missed compared to attended changed over time

# %%
# Determine the number of appointments per month by appointment status
ar_status = ar.groupby(['appointment_month', 'appointment_status']).sum().reset_index()
ar_status
# Out:
#    appointment_month appointment_status  count_of_appointments
# 0         2020-01-01           Attended               24538291
# 1         2020-01-01                DNA                1298269
# 2         2020-01-01            Unknown                1362736
# 3         2020-02-01           Attended               21640067
# 4         2020-02-01                DNA                1215154
# ..               ...                ...                    ...
# 85        2022-05-01                DNA                1199518
# 86        2022-05-01            Unknown                 952049
# 87        2022-06-01           Attended               23715317
# 88        2022-06-01                DNA                1167790
# 89        2022-06-01            Unknown                 944971
#
# [90 rows x 3 columns]

# %%
# Pivot the ar_status DataFrame 
ar_missed = ar_status.pivot_table(index='appointment_month', columns='appointment_status', values='count_of_appointments')

# Calculate the ratio of missed to attended appointments for each month
ar_missed['missed_to_attended_ratio'] = ar_missed['DNA'] / ar_missed['Attended']

# Display the resulting dataframe
ar_missed.head()
# Out:
# appointment_status  Attended      DNA  Unknown  missed_to_attended_ratio
# appointment_month
# 2020-01-01          24538291  1298269  1362736                  0.052908
# 2020-02-01          21640067  1215154  1249400                  0.056153
# 2020-03-01          20718865  1166314  2168289                  0.056292
# 2020-04-01          13982824   478766  1546291                  0.034240
# 2020-05-01          14962850   449057  1005305                  0.030011

# %%
# Create a line plot to answer the question.
ax = sns.lineplot(x='appointment_month', y='missed_to_attended_ratio', data=ar_missed)

# Customise tick labels for y axis
ax.set_yticklabels(['', '3.0%', '3.5%', '4.0%', '4.5%', '5.0%', '5.5%'])

# Specify the labels
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Missed to Attended Appointments")
ax.set_title("The Percentage of Missed to Attended Appointments Over Time")
# Out:
# Text(0.5, 1.0, 'The Percentage of Missed to Attended Appointments Over Time')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data.
#
# From this visualisation you can see the percentage of GP appointments that were missed per month went down from 5.5% to 3.5% during the start of 2020, and has been on an uptrend ever since.

# %% [markdown]
# Determine the number of new Covid cases in the UK over time

# %%
# Access NHS API - Code copied from NHS developers guide
# https://coronavirus.data.gov.uk/details/developers-guide/main-api
from requests import get


def get_data(url):
    response = get(url, timeout=10)
    
    if response.status_code >= 400:
        raise RuntimeError(f'Request failed: { response.text }')
        
    return response.json()
    

if __name__ == '__main__':
    endpoint = (
        'https://api.coronavirus.data.gov.uk/v1/data?'
        'filters=areaType=nation;areaName=england&'
        'structure={"date":"date","newCasesBySpecimenDate":"newCasesBySpecimenDate"}'
    )
    
    data = get_data(endpoint)
    
    # Retrieve the data
    cases_by_date = data.get('data', [])

    # Create a pandas DataFrame using the Covid data
    cases = pd.DataFrame(cases_by_date)

    print(cases)
# Out:
#             date  newCasesBySpecimenDate
# 0     2023-05-24                     527
# 1     2023-05-23                     923
# 2     2023-05-22                    1036
# 3     2023-05-21                     852
# 4     2023-05-20                     696
# ...          ...                     ...
# 1206  2020-02-03                      18
# 1207  2020-02-02                       1
# 1208  2020-02-01                       0
# 1209  2020-01-31                       0
# 1210  2020-01-30                       1
#
# [1211 rows x 2 columns]

# %%
# Convert the 'date' column data type to datetime
cases['date'] = pd.to_datetime(cases['date'])

# Extract the month and year from the 'date' column
cases['month'] = cases['date'].dt.to_period('M')

# Group the DataFrame by 'month' and calculate the sum of new cases per month
sum_cases = cases.groupby('month')['newCasesBySpecimenDate'].sum().reset_index()

# Rename the DataFrames columns
sum_cases.columns = ['month', 'sum_new_cases']

# Filter months column to line up with the other graphs
sum_cases = sum_cases[sum_cases['month'] <= '2022-06']

# Convert month column back to datetime
sum_cases['month'] = sum_cases['month'].dt.to_timestamp()

# Reset the index
sum_cases.reset_index(drop=True, inplace=True)

# View the DataFrame
sum_cases.head()
# Out:
#        month  sum_new_cases
# 0 2020-01-01              1
# 1 2020-02-01             68
# 2 2020-03-01          32857
# 3 2020-04-01         118409
# 4 2020-05-01          68274

# %%
# Create a line plot to show Covid cases over time
ax = sns.lineplot(data=sum_cases, x='month', y='sum_new_cases')

# Specify the labels
ax.set_xlabel('Month')
ax.set_ylabel('Sum of New Cases (Millions)')
ax.set_title('Montlhy New COVID Cases')
# Out:
# Text(0.5, 1.0, 'Montlhy New COVID Cases')

# %% [markdown]
# A Seaborn lineplot was used to display the data as lineplots are useful displaying timeseries data.
#
# From this visualisation you can see the number of new covid cases over time during the timeframe that we are analysing GP data.

# %% [markdown]
# Determine whether Covid had an impact on the rate at which patients missed appointments.

# %%
# Create a figure and axis to house a dual axis lineplot analysing the impact of
# covid on patients missing gp appointments
fig, ax = plt.subplots(figsize=(10, 6))

# Create a lineplot for montly missed to attended appointments 
sns.lineplot(x='appointment_month', y='missed_to_attended_ratio', data=ar_missed, ax=ax)

# Specify labels for the lineplot
ax.set_xlabel("Appointment Month")
ax.set_ylabel("Missed to Attended Appointments (%)")
ax.set_title("Missed to Attended Appointments and Monthly New COVID Cases")

# Create a second y axis
ax2 = ax.twinx()

# Create a lineplot for montly new coronavirus cases
sns.lineplot(data=sum_cases, x='month', y='sum_new_cases', ax=ax2, color='red')

# Specify labels for the second y axis
ax2.set_ylabel('Sum of New Cases (Millions)')

# Create a legend for the dual axis lineplot
ax.legend(labels=["Missed to Attended Appointments"], loc="upper left")
ax2.legend(labels=["Monthly New Covid Cases"], loc="upper right")

# %%
# Calculate the correlation coefficient of the two varaibles
correlation_coefficient = np.corrcoef\
    (sum_cases['sum_new_cases'], ar_missed['missed_to_attended_ratio'] )[0, 1]

# View the output
print("The correlation coefficient of new cases and missed to attended appointments is",
      correlation_coefficient)
# Out:
# The correlation coefficient of new cases and missed to attended appointments is 0.30304831763771

# %% [markdown]
# A Maplotlib dual axis as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data. Using a dual axis lineplot made it possible to visualise a comparioson  of the corrolation of two seperate variables.
#
# From this visualisation and the corrolation coefficient of the two variables it is clear that there is a low corrolation between patients missing appointments and covid. This validates our other analysis as if a high correlation between Covid cases missed appointments data was observed, the data might not be suitable for extrapolating findings beyond the pandemic, as the current circumstances no longer reflect the conditions during the pandemic.

# %% [markdown]
# Determine whether Covid had an impact on capacity utilisation of GP appointments

# %%
# Create a new DataFrame to 
utilisation_covid = sum_cases[sum_cases['month'] >= '2021-08'].reset_index(drop=True)
utilisation_covid['capacity_utilisation'] = ar_df['capcacity_utilisation'].copy()

# %%
# Create the figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Create a lineplot for montly new coronavirus cases
sns.lineplot(x='month', y='sum_new_cases', data=utilisation_covid, ax=ax1)

# Specify labels for the lineplot
ax1.set_xlabel('Month')
ax1.set_ylabel('Sum of New Cases (Millions)')
ax1.set_title('Monthly New Covid Cases and Capacity Utilisation')

# Create the second axis
ax2 = ax1.twinx()

# Plot the lineplot for montly capacity utilisation
sns.lineplot(x='month', y='capacity_utilisation', data=utilisation_covid, ax=ax2, color='red')

# Specify labels
ax2.set_ylabel('Capacity Utilisation')

# Create a legend for the dual axis lineplot
ax1.legend(labels=['Sum of New Cases'], loc='upper left')
ax2.legend(labels=['Capacity Utilisation'], loc='upper right')

# %%
# Calculate the correlation coefficient of the two varaibles
correlation_coefficient = np.corrcoef\
    (utilisation_covid['sum_new_cases'],\
     utilisation_covid['capacity_utilisation'] )[0, 1]

# View the output
print("The correlation coefficient of new cases and capacity utilisation is",
    correlation_coefficient)
# Out:
# The correlation coefficient of new cases and capacity utilisation is -0.09716393903485203

# %% [markdown]
# A Maplotlib dual axis as lineplots are an effective tool for displaying and analysing trends and patterns in time-series data. Using a dual axis lineplot made it possible to visualise a comparioson  of the corrolation of two seperate variables.
#
# From this visualisation and the corrolation coefficient of the two variables it is clear that there is a low negative corrolation between capacity utilisation of appointments and covid. This validates our other analysis as if a high correlation between Covid cases and capacity utilisation data was observed, the data might not be suitable for extrapolating findings beyond the pandemic, as the current circumstances no longer reflect the conditions during the pandemic.

# %% [markdown]
# What is the missed to attend ratio / proportion of missed appointments for each time range between the appointment and when it was booked?

# %%
# Group the DataFrame by appointment status and time between booking and appointment
grouped = ar.groupby(['appointment_status', 'time_between_book_and_appointment']).sum()

# Calculate the missed to attended ratio for each time range
missed_attended_ratio = grouped.loc['DNA'] / grouped.loc['Attended']

# View the output
print(missed_attended_ratio)
# Out:
#                                    count_of_appointments
# time_between_book_and_appointment
# 1 Day                                           0.042114
# 15  to 21 Days                                  0.091588
# 2 to 7 Days                                     0.062978
# 22  to 28 Days                                  0.096161
# 8  to 14 Days                                   0.082477
# More than 28 Days                               0.121929
# Same Day                                        0.018432
# Unknown / Data Quality                          0.050717

# %%
# Group the ar DataFrame by appointment status and time between booking and appointment
status_grouped = ar.groupby(['appointment_status',
                             'time_between_book_and_appointment']).sum()

# Calculate the missed-to-attended ratio for the different time between bookings.
missed_booking_time = status_grouped.loc['DNA'] / status_grouped.loc['Attended']

# Create an order for the output of missed_booking_time
day_order = ['Same Day', '1 Day', '2 to 7 Days', '8  to 14 Days', '15  to 21 Days',
             '22  to 28 Days', 'More than 28 Days']

# Order the output
time_sorted = missed_booking_time.reindex(day_order)

# Rename the count of appointments column
time_sorted.rename(columns={'count_of_appointments':\
                            'proportion_of_missed_appointments'}, inplace=True)

# View the DataFrame
time_sorted
# Out:
#                                    proportion_of_missed_appointments
# time_between_book_and_appointment
# Same Day                                                    0.018432
# 1 Day                                                       0.042114
# 2 to 7 Days                                                 0.062978
# 8  to 14 Days                                               0.082477
# 15  to 21 Days                                              0.091588
# 22  to 28 Days                                              0.096161
# More than 28 Days                                           0.121929

# %%
# Move time_between_book_and_appointment out of the index
time_sorted = time_sorted.reset_index()

# %%
# Create a bar chart to show the proportion of appointments missed
# by time betwen book and appointment
ax = sns.barplot(x='time_between_book_and_appointment', 
                 y='proportion_of_missed_appointments', data=time_sorted)

# Set axis title
ax.set_title('Proportion of Appointments Missed by Time Between Book and\
  Appointment)', size=25)

# Set axis labels
ax.set_xlabel('Time Between Book and Appointment', size=20)
ax.set_ylabel('Proportioin of Appointments Missed', size=20)
# Out:
# Text(0, 0.5, 'Proportioin of Appointments Missed')

# %% [markdown]
# A Seaborn barplot was used to display the data as barplots are an effective tool for displaying catigorical data.
#
# From this visualisation we can tell the longer it takes for a patient to see a GP / Doctor, the more likley they are to miss the appointment. I.E. there is a strong positive correlation between the amount of time it takes to see a doctor and the liklihood of the appointment being missed.

# %% [markdown]
# Is there a large difference in the time taken for patients to see GPs depending on location?

# %%
# Group the ar DataFrame by location (icb_ons_code)
icb_grouped = ar.groupby('icb_ons_code')

# Calculate the total number of appointments for each location
total_appointments = icb_grouped['count_of_appointments'].sum()

# Filter the DataFrame for appointments on the same day for each location
same_day = icb_grouped.apply(lambda x: x[x['time_between_book_and_appointment'] == 'Same Day']['count_of_appointments'].sum())

# Calculate the ratio of appointments on the same day for each location
ratio_same_day = (same_day / total_appointments)

# Sort the ratios in ascending order
sorted_ratios = ratio_same_day.sort_values()

# Print the sorted ratios
sorted_ratios
# Out:
# icb_ons_code
# E54000041    0.396765
# E54000043    0.412949
# E54000022    0.420651
# E54000040    0.423616
# E54000051    0.429173
# E54000061    0.432939
# E54000058    0.435601
# E54000037    0.437750
# E54000060    0.443365
# E54000050    0.443977
# E54000052    0.444741
# E54000024    0.446418
# E54000027    0.446883
# E54000032    0.446970
# E54000039    0.447176
# E54000038    0.447360
# E54000026    0.447916
# E54000053    0.450534
# E54000042    0.451251
# E54000057    0.456481
# E54000015    0.460421
# E54000013    0.463329
# E54000048    0.463586
# E54000054    0.464397
# E54000036    0.470035
# E54000029    0.470812
# E54000031    0.472438
# E54000044    0.473337
# E54000030    0.474017
# E54000023    0.475151
# E54000010    0.476206
# E54000025    0.484305
# E54000008    0.486946
# E54000019    0.489883
# E54000062    0.492834
# E54000011    0.494010
# E54000034    0.495890
# E54000055    0.498175
# E54000059    0.504858
# E54000028    0.515756
# E54000056    0.518400
# ...

# %% [markdown]
# The list above shows that there is a large variance in the proportion of appointments that are done on the same day they were booked depending on which location they are. While further investigation is needed before coming to final conclusions, the list above indicates that waiting times for different locations may vary significantly. With one location only having 39% of their appointments on the same day they were booked compared to 53% in another.

# %% [markdown]
# ### Provide a summary of your findings and recommendations based on the analysis.

# %% [markdown]
# •	Covid doesn’t appear to have skewed the relevant GP data.
#
# •	The overall capacity utilisation of the NHS network is at an acceptable level, as a result it appears the NHS has enough staff.
#
# •	People are more likely to miss appointments when they have to wait longer to see a GP/Doctor.
#
# •	According to an Oxford newspaper there’s a high variance in the waiting times for doctors by practice. This is supported by research I did which shows the amount of appointments which happened the same day as booking varies significantly by location.
# https://www.oxfordmail.co.uk/news/23178373.gp-practices-oxfordshire-longest-waiting-times/
#
# •	Different waiting times suggests different capacity utilisations in practices and locations. While the NHS have enough staff, they may not be in the right locations to meet the demands in appointments from patients.
#
# •	Since the amount of phone appointments doubled over the past few years, it may be possible to reduce wait times by making under-utilised GP practices take some of the phone appointments from practices that have long wait times/ high capacity utilisation.
#
# •	If the NHS can use phone appointments across practices/locations to reduce waiting times they may see a reduction in the amount of missed appointments.
#
# •	Recommendation: More research/trials must be carried out to determine whether there’s causation in the relationship between waiting times and missed appointments or whether it’s only correlational.
#
# •	Limitation: because the data collection methods between each GP varies, the data doesn’t give a complete view of GP activity so may not give an accurate picture of GP workload. Because of this, no changes to the NHS should be actioned using the findings without further analysis.
